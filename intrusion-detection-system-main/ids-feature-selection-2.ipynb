# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Dell\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\Dell\anaconda3\lib\site-packages\numpy\.libs\libopenblas.xwydx2ikjw2nmtwsfyngfuwkqu3lytcz.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv("./merged_pre_processed.csv", low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0           srcip  sport           dstip dsport proto state  \
# 0      613404      59.166.0.7  27382   149.171.126.8     53   udp   CON
# 1      671852  149.171.126.18  47439    175.45.176.3     53   udp   INT
# 2      391447      59.166.0.7  15578   149.171.126.1  34872   tcp   FIN
# 3      591363    175.45.176.0  16421  149.171.126.15    179   tcp   FIN
# 4      478920      59.166.0.2  33699   149.171.126.2   5190   tcp   FIN
#
#         dur  sbytes  dbytes  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# 0  0.001046     132     164  ...                       2           3
# 1  0.000007     264       0  ...                      57          57
# 2  0.009837    2438   18508  ...                       3           2
# 3  1.887100    1006     702  ...                       5           2
# 4  0.004115    1036    2262  ...                       7           7
#
#    ct_dst_ltm ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0           1           9                 1                 1               1
# 1          56          56                56                20              57
# 2           3           6                 1                 1               1
# 3           1           2                 2                 1               2
# 4           3           3                 2                 1               3
#
#    attack_cat  Label
# 0      Normal      0
# 1      Normal      0
# 2      Normal      0
# 3      Normal      0
# 4      Normal      0
#
# [5 rows x 48 columns]

# %%
df.drop(["Unnamed: 0"], axis=1,inplace=True)

# %%
df.head()
# Out:
#             srcip  sport           dstip dsport proto state       dur  sbytes  \
# 0      59.166.0.7  27382   149.171.126.8     53   udp   CON  0.001046     132
# 1  149.171.126.18  47439    175.45.176.3     53   udp   INT  0.000007     264
# 2      59.166.0.7  15578   149.171.126.1  34872   tcp   FIN  0.009837    2438
# 3    175.45.176.0  16421  149.171.126.15    179   tcp   FIN  1.887100    1006
# 4      59.166.0.2  33699   149.171.126.2   5190   tcp   FIN  0.004115    1036
#
#    dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst ct_dst_ltm  \
# 0     164    31  ...                       2           3          1
# 1       0    60  ...                      57          57         56
# 2   18508    31  ...                       3           2          3
# 3     702   254  ...                       5           2          1
# 4    2262    31  ...                       7           7          3
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            9                 1                 1               1
# 1           56                56                20              57
# 2            6                 1                 1               1
# 3            2                 2                 1               2
# 4            3                 2                 1               3
#
#    attack_cat  Label
# 0      Normal      0
# 1      Normal      0
# 2      Normal      0
# 3      Normal      0
# 4      Normal      0
#
# [5 rows x 47 columns]

# %%
df.tail()
# Out:
#               srcip  sport           dstip dsport proto state       dur  \
# 92744  175.45.176.3   1043  149.171.126.18     53   udp   INT  0.000003
# 92745  175.45.176.1  13540  149.171.126.10     80   tcp   FIN  3.393675
# 92746  175.45.176.0  34233  149.171.126.15   1723   tcp   FIN  0.586488
# 92747  175.45.176.1  61247  149.171.126.17    110   tcp   FIN  2.014088
# 92748  175.45.176.1   6870  149.171.126.17     80   tcp   FIN  0.771105
#
#        sbytes  dbytes  sttl  ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  \
# 92744     114       0   254  ...                      34          34
# 92745    1194    3802    62  ...                       2           1
# 92746     756     268   254  ...                       6           2
# 92747     978    2844    62  ...                       1           1
# 92748     840    2026    62  ...                       2           1
#
#       ct_dst_ltm  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 92744         19           19                19                19
# 92745          1            1                 1                 1
# 92746          1            2                 1                 1
# 92747          1            1                 1                 1
# 92748          1            1                 1                 1
#
#        ct_dst_src_ltm  attack_cat  Label
# 92744              34     Generic      1
# 92745               1     Generic      1
# 92746               2    Fuzzers       1
# 92747               2    Exploits      1
# 92748               2         DoS      1
#
# [5 rows x 47 columns]

# %%
df.dtypes
# Out:
# srcip                object
# sport                 int64
# dstip                object
# dsport               object
# proto                object
# state                object
# dur                 float64
# sbytes                int64
# dbytes                int64
# sttl                  int64
# dttl                  int64
# sloss                 int64
# dloss                 int64
# service              object
# Sload               float64
# Dload               float64
# Spkts                 int64
# Dpkts                 int64
# swin                  int64
# dwin                  int64
# stcpb                 int64
# dtcpb                 int64
# smeansz               int64
# dmeansz               int64
# trans_depth           int64
# res_bdy_len           int64
# Sjit                float64
# Djit                float64
# Stime                 int64
# Ltime                 int64
# Sintpkt             float64
# Dintpkt             float64
# tcprtt              float64
# synack              float64
# ackdat              float64
# is_sm_ips_ports       int64
# ct_state_ttl          int64
# ct_ftp_cmd           object
# ct_srv_src            int64
# ct_srv_dst            int64
# ct_dst_ltm            int64
# ct_src_ ltm           int64
# ct_src_dport_ltm      int64
# ct_dst_sport_ltm      int64
# ct_dst_src_ltm        int64
# attack_cat           object
# Label                 int64
# dtype: object

# %% [markdown]
# ### Data Correlation

# %%
categorical_columns = ['srcip', 'dstip', 'proto', 'dsport', 'state', 'service', 'ct_ftp_cmd', 'attack_cat', ]
# categorical_columns = [ 'proto',  'state', 'service', 'ct_ftp_cmd', 'attack_cat', ]

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

df2 = df.copy()

df2[categorical_columns] = enc.fit_transform(df2[categorical_columns])

# %%
df2.head()
# Out:
#    srcip  sport  dstip  dsport  proto  state       dur  sbytes  dbytes  sttl  \
# 0   32.0  27382   24.0  9347.0  117.0    2.0  0.001046     132     164    31
# 1   12.0  47439   29.0  9347.0  117.0    5.0  0.000007     264       0    60
# 2   32.0  15578    7.0  5466.0  111.0    4.0  0.009837    2438   18508    31
# 3   21.0  16421   13.0  1821.0  111.0    4.0  1.887100    1006     702   254
# 4   27.0  33699   18.0  9099.0  111.0    4.0  0.004115    1036    2262    31
#
#    ...  ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_dst_ltm  ct_src_ ltm  \
# 0  ...         0.0           2           3           1            9
# 1  ...         0.0          57          57          56           56
# 2  ...         0.0           3           2           3            6
# 3  ...         0.0           5           2           1            2
# 4  ...         0.0           7           7           3            3
#
#    ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  attack_cat  Label
# 0                 1                 1               1         8.0      0
# 1                56                20              57         8.0      0
# 2                 1                 1               1         8.0      0
# 3                 2                 1               2         8.0      0
# 4                 2                 1               3         8.0      0
#
# [5 rows x 47 columns]

# %%
df2.dtypes
# Out:
# srcip               float64
# sport                 int64
# dstip               float64
# dsport              float64
# proto               float64
# state               float64
# dur                 float64
# sbytes                int64
# dbytes                int64
# sttl                  int64
# dttl                  int64
# sloss                 int64
# dloss                 int64
# service             float64
# Sload               float64
# Dload               float64
# Spkts                 int64
# Dpkts                 int64
# swin                  int64
# dwin                  int64
# stcpb                 int64
# dtcpb                 int64
# smeansz               int64
# dmeansz               int64
# trans_depth           int64
# res_bdy_len           int64
# Sjit                float64
# Djit                float64
# Stime                 int64
# Ltime                 int64
# Sintpkt             float64
# Dintpkt             float64
# tcprtt              float64
# synack              float64
# ackdat              float64
# is_sm_ips_ports       int64
# ct_state_ttl          int64
# ct_ftp_cmd          float64
# ct_srv_src            int64
# ct_srv_dst            int64
# ct_ftp_cmd        0.505591  0.168269  0.299979  0.023648  0.042482 -0.457978
# ct_srv_src       -0.333861 -0.077667 -0.101303  0.305719  0.208470  0.451674
# ct_srv_dst       -0.334316 -0.081557 -0.102351  0.308814  0.207085  0.452041
# ct_dst_ltm       -0.244694 -0.074704 -0.031422  0.293000  0.192435  0.360947
# ct_src_ ltm      -0.256686 -0.123739 -0.040011  0.214741  0.153597  0.383107
# ct_src_dport_ltm -0.325884 -0.101400 -0.078846  0.284459  0.173657  0.427165
# ct_dst_sport_ltm -0.350951 -0.139102 -0.084401  0.258044  0.162511  0.449799
# ct_dst_src_ltm   -0.415023 -0.110676 -0.154126  0.285294  0.180105  0.506998
# attack_cat        0.347681  0.083930  0.301351  0.328367  0.144454 -0.256874
# Label            -0.628910 -0.236604 -0.526779 -0.103665 -0.082655  0.650307
#
#                        dur    sbytes    dbytes      sttl  ...  ct_ftp_cmd  \
# srcip            -0.070278 -0.002834  0.106759 -0.604387  ...    0.505591
# sport            -0.025382  0.011283  0.044423 -0.260891  ...    0.168269
# dstip            -0.030037 -0.004235  0.055527 -0.479346  ...    0.299979
# dsport           -0.082095 -0.020010  0.099063 -0.120110  ...    0.023648
# proto            -0.145414 -0.000500  0.002388 -0.076748  ...    0.042482
# state             0.000980 -0.029431 -0.040153  0.681951  ...   -0.457978
# dur               1.000000  0.225267  0.211833 -0.003769  ...   -0.002579
# sbytes            0.225267  1.000000  0.014172 -0.015023  ...   -0.007424
# dbytes            0.211833  0.014172  1.000000 -0.142635  ...    0.075441
# sttl             -0.003769 -0.015023 -0.142635  1.000000  ...   -0.621200
# dttl              0.115390  0.068755  0.029965 -0.032512  ...   -0.063017
# sloss             0.236107  0.992883  0.031745 -0.052061  ...    0.020802
# dloss             0.211200  0.012504  0.994159 -0.176049  ...    0.102200
# service           0.013756  0.086805  0.014239 -0.166560  ...    0.028900
# Sload            -0.076231 -0.018471 -0.063711  0.364946  ...   -0.263095
# Dload            -0.053062 -0.006398  0.113026 -0.423595  ...    0.289475
# Spkts             0.304483  0.915403  0.324433 -0.144432  ...    0.086295
# Dpkts             0.246395  0.149806  0.972174 -0.213094  ...    0.129238
# swin              0.073610  0.047087  0.161437 -0.555231  ...    0.367385
# dwin              0.073721  0.047120  0.161544 -0.555738  ...    0.367666
# stcpb             0.056389  0.033640  0.124407 -0.441433  ...    0.293360
# dtcpb             0.055576  0.040122  0.123493 -0.440788  ...    0.288953
# smeansz           0.087422  0.216361 -0.047041 -0.103528  ...    0.013590
# dmeansz           0.075192 -0.000685  0.468314 -0.556643  ...    0.310653
# trans_depth       0.026676  0.005107  0.054991 -0.066886  ...    0.001403
# res_bdy_len       0.123604  0.004615  0.528714 -0.061663  ...    0.031041
# Sjit              0.183012 -0.000415  0.003406  0.028031  ...   -0.018792
# Djit              0.196773 -0.002750  0.093960 -0.156357  ...    0.097190
# Stime             0.020475  0.006707 -0.088275  0.636673  ...   -0.910158
# Ltime             0.020479  0.006708 -0.088274  0.636673  ...   -0.910158
# Sintpkt           0.202085 -0.002065 -0.006989 -0.049442  ...    0.033857
# tcprtt             -0.236296   -0.246230   -0.215224    -0.221013
# synack             -0.218238   -0.228008   -0.200684    -0.205605
# ackdat             -0.237834   -0.247227   -0.214681    -0.220942
# is_sm_ips_ports    -0.021097   -0.020469   -0.016857    -0.019059
# ct_state_ttl        0.459581    0.462919    0.370048     0.400303
# ct_ftp_cmd         -0.283460   -0.283104   -0.224468    -0.239423
# ct_srv_src          1.000000    0.978981    0.850200     0.805869
# ct_srv_dst          0.978981    1.000000    0.859131     0.801590
# ct_dst_ltm          0.850200    0.859131    1.000000     0.928418
# ct_src_ ltm         0.805869    0.801590    0.928418     1.000000
# ct_src_dport_ltm    0.871370    0.873356    0.979458     0.935035
# ct_dst_sport_ltm    0.804262    0.807815    0.885587     0.845183
# ct_dst_src_ltm      0.965669    0.969331    0.857069     0.809973
# attack_cat          0.128694    0.136602    0.156306     0.116986
# Label               0.350884    0.351436    0.277741     0.305858
#
#                   ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# srcip                    -0.325884         -0.350951       -0.415023
# sport                    -0.101400         -0.139102       -0.110676
# dstip                    -0.078846         -0.084401       -0.154126
# dsport                    0.284459          0.258044        0.285294
# proto                     0.173657          0.162511        0.180105
# state                     0.427165          0.449799        0.506998
# dur                      -0.085274         -0.085285       -0.102566
# sbytes                   -0.023066         -0.023350       -0.028317
# dbytes                   -0.070369         -0.076262       -0.085347
# sttl                      0.429409          0.455265        0.521561
# dttl                     -0.293231         -0.301648       -0.337223
# sloss                    -0.044534         -0.045856       -0.053883
# dloss                    -0.089901         -0.096283       -0.108389
# service                   0.025789          0.031154        0.010307
# Sload                     0.189484          0.195747        0.242074
# Dload                    -0.210480         -0.216628       -0.251045
# Spkts                    -0.094353         -0.098545       -0.113778
# Dpkts                    -0.113630         -0.121162       -0.136784
# swin                     -0.445863         -0.472090       -0.525059
# dwin                     -0.445544         -0.471774       -0.525093
# stcpb                    -0.354176         -0.375375       -0.417927
# dtcpb                    -0.354919         -0.375529       -0.418583
# smeansz                  -0.165456         -0.175902       -0.177329
# dmeansz                  -0.300511         -0.314194       -0.361864
# trans_depth              -0.082330         -0.084502       -0.101392
# res_bdy_len              -0.033182         -0.034258       -0.040030
# Sjit                     -0.038090         -0.037121       -0.039032
# Djit                     -0.107125         -0.109602       -0.127251
# Stime                     0.298155          0.322117        0.373484
# Ltime                     0.298154          0.322116        0.373484
# Sintpkt                  -0.029095         -0.026358       -0.036140
# Dintpkt                  -0.028074         -0.026603       -0.033192
# tcprtt                   -0.182097         -0.185158       -0.204671
# synack                   -0.170481         -0.173725       -0.189862
# ackdat                   -0.180937         -0.183593       -0.205157
# is_sm_ips_ports          -0.013209         -0.012187       -0.017263
# ct_state_ttl              0.456932          0.484237        0.551055
# ct_ftp_cmd               -0.297480         -0.319200       -0.366462
# ct_srv_src                0.871370          0.804262        0.965669
# ct_srv_dst                0.873356          0.807815        0.969331
# ct_dst_ltm                0.979458          0.885587        0.857069
# ct_src_ ltm               0.935035          0.845183        0.809973
# ct_src_dport_ltm          1.000000          0.910491        0.884731
# ct_dst_sport_ltm          0.910491          1.000000        0.827368
# ct_dst_src_ltm            0.884731          0.827368        1.000000
# attack_cat                0.093313          0.095109        0.067679
# Label                     0.373941          0.400475        0.452189
#
#                   attack_cat     Label
# srcip               0.347681 -0.628910
# sport               0.083930 -0.236604
# dstip               0.301351 -0.526779
# dsport              0.328367 -0.103665
# proto               0.144454 -0.082655
# state              -0.256874  0.650307
# dur                -0.097517  0.025444
# sbytes             -0.008339  0.010864
# dbytes              0.070379 -0.116429
# sttl               -0.536942  0.911836
# dttl               -0.433857  0.175306
# sloss               0.007181 -0.023556
# dloss               0.084874 -0.145537
# service             0.177039 -0.026516
# Sload              -0.187156  0.311258
# Dload               0.255955 -0.445515
# Spkts               0.056699 -0.117350
# Dpkts               0.099729 -0.180920
# swin                0.039154 -0.454297
# dwin                0.038728 -0.453590
# stcpb               0.031446 -0.361598
# dtcpb               0.028311 -0.360240
# smeansz            -0.085530 -0.060535
# dmeansz             0.266292 -0.472437
# trans_depth        -0.012556 -0.008820
# res_bdy_len         0.028184 -0.041607
# Sjit               -0.135807  0.028113
# Djit                0.012625 -0.105230
# Stime              -0.386842  0.675014
# Ltime              -0.386842  0.675014
# Sintpkt             0.000225 -0.040199
# Dintpkt            -0.034565 -0.019601
# tcprtt             -0.467859  0.259557
# synack             -0.450888  0.236391
# ackdat             -0.451754  0.264644
# is_sm_ips_ports     0.017962 -0.031333
# ct_state_ttl       -0.407913  0.908703
# ct_ftp_cmd          0.357907 -0.626652
# ct_srv_src          0.128694  0.350884
# ct_srv_dst          0.136602  0.351436
# ct_dst_ltm          0.156306  0.277741
# ct_src_ ltm         0.116986  0.305858
# ct_src_dport_ltm    0.093313  0.373941
# ct_dst_sport_ltm    0.095109  0.400475
# ct_dst_src_ltm      0.067679  0.452189
# attack_cat          1.000000 -0.573244
# Label              -0.573244  1.000000
#
# [47 rows x 47 columns]

# %%
df2 = df2[[col for col in df2 if df[col].nunique() > 1]]# keep columns where there are more than 1 unique values

corr = df2.corr()

plt.figure(figsize=(15,12))

sns.heatmap(corr)

plt.show()

# %% [markdown]
# ##### Dropping the columns the columns which have very less correlation with the end result
# Those columns which have correlation between -0.3 to 0.3 will be dropped
# Also source and destination ip address columns are dropped as, they are in string format and even if they are encoded it will be inefficient

# %%
columns_drop = ['sport', 'dsport', 'proto', 'sbytes', 'dbytes', 'dur', 'ct_dst_ltm', 
                'is_sm_ips_ports', 'tcprtt', 'synack', 'ackdat', 'Sintpkt', 'Dintpkt',
               'Djit', 'Sjit', 'res_bdy_len','trans_depth', 'smeansz',
               'service', 'dloss', 'sloss', 'dttl', 'Spkts', 'Dpkts', 'srcip', 'dstip']

# %%
df = df.drop(columns_drop, axis=1)
df2 = df2.drop(columns_drop, axis=1)

# %%
df2.corr()
# Out:
#                      state      sttl     Sload     Dload      swin      dwin  \
# state             1.000000  0.681951  0.372953 -0.139438 -0.210945 -0.211921
# sttl              0.681951  1.000000  0.364946 -0.423595 -0.555231 -0.555738
# Sload             0.372953  0.364946  1.000000 -0.176396 -0.389773 -0.389814
# Dload            -0.139438 -0.423595 -0.176396  1.000000  0.412755  0.413046
# swin             -0.210945 -0.555231 -0.389773  0.412755  1.000000  0.999339
ct_ftp_cmd  ct_srv_src  ct_srv_dst  ct_src_ ltm  \
# state              -0.457978    0.451674    0.452041     0.383107
# sttl               -0.621200    0.433052    0.433117     0.368124
# Sload              -0.263095    0.204323    0.207338     0.175438
# Dload               0.289475   -0.147552   -0.161103    -0.167884
# swin                0.367385   -0.465320   -0.475939    -0.419677
# dwin                0.367666   -0.465311   -0.475923    -0.419484
# stcpb               0.293360   -0.370707   -0.378235    -0.333720
# dtcpb               0.288953   -0.371952   -0.379427    -0.334755
# dmeansz             0.310653   -0.282457   -0.290898    -0.271131
# Stime              -0.910158    0.268872    0.269172     0.238831
# Ltime              -0.910158    0.268872    0.269172     0.238831
# ct_state_ttl       -0.598000    0.459581    0.462919     0.400303
# ct_ftp_cmd          1.000000   -0.283460   -0.283104    -0.239423
# ct_srv_src         -0.283460    1.000000    0.978981     0.805869
# ct_srv_dst         -0.283104    0.978981    1.000000     0.801590
# ct_src_ ltm        -0.239423    0.805869    0.801590     1.000000
# ct_src_dport_ltm   -0.297480    0.871370    0.873356     0.935035
# ct_dst_sport_ltm   -0.319200    0.804262    0.807815     0.845183
# ct_dst_src_ltm     -0.366462    0.965669    0.969331     0.809973
# attack_cat          0.357907    0.128694    0.136602     0.116986
# Label              -0.626652    0.350884    0.351436     0.305858
#
#                   ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# state                     0.427165          0.449799        0.506998
# sttl                      0.429409          0.455265        0.521561
# Sload                     0.189484          0.195747        0.242074
# Dload                    -0.210480         -0.216628       -0.251045
# swin                     -0.445863         -0.472090       -0.525059
# dwin                     -0.445544         -0.471774       -0.525093
# stcpb                    -0.354176         -0.375375       -0.417927
# dtcpb                    -0.354919         -0.375529       -0.418583
# dmeansz                  -0.300511         -0.314194       -0.361864
# Stime                     0.298155          0.322117        0.373484
# Ltime                     0.298154          0.322116        0.373484
# ct_state_ttl              0.456932          0.484237        0.551055
# ct_ftp_cmd               -0.297480         -0.319200       -0.366462
# ct_srv_src                0.871370          0.804262        0.965669
# ct_srv_dst                0.873356          0.807815        0.969331
# ct_src_ ltm               0.935035          0.845183        0.809973
# ct_src_dport_ltm          1.000000          0.910491        0.884731
# ct_dst_sport_ltm          0.910491          1.000000        0.827368
# ct_dst_src_ltm            0.884731          0.827368        1.000000
# attack_cat                0.093313          0.095109        0.067679
# Label                     0.373941          0.400475        0.452189
#
#                   attack_cat     Label
# state              -0.256874  0.650307
# sttl               -0.536942  0.911836
# Sload              -0.187156  0.311258
# Dload               0.255955 -0.445515
# swin                0.039154 -0.454297
# dwin                0.038728 -0.453590
# stcpb               0.031446 -0.361598
# dtcpb               0.028311 -0.360240
# dmeansz             0.266292 -0.472437
# Stime              -0.386842  0.675014
# Ltime              -0.386842  0.675014
# ct_state_ttl       -0.407913  0.908703
# ct_ftp_cmd          0.357907 -0.626652
# ct_srv_src          0.128694  0.350884
# ct_srv_dst          0.136602  0.351436
# ct_src_ ltm         0.116986  0.305858
# ct_src_dport_ltm    0.093313  0.373941
# ct_dst_sport_ltm    0.095109  0.400475
# ct_dst_src_ltm      0.067679  0.452189
# attack_cat          1.000000 -0.573244
# Label              -0.573244  1.000000
#
# [21 rows x 21 columns]

# %%
df2 = df2[[col for col in df2 if df[col].nunique() > 1]]# keep columns where there are more than 1 unique values

corr = df2.corr()

plt.figure(figsize=(15,12))

sns.heatmap(corr)

plt.show()

# %%
df2.head()
# Out:
#    state  sttl         Sload         Dload  swin  dwin       stcpb  \
# 0    2.0    31  5.047801e+05  6.271510e+05     0     0           0
# 1    5.0    60  1.508571e+08  0.000000e+00     0     0           0
# 2    4.0    31  1.930670e+06  1.467602e+07   255   255  3749459648
# 3    4.0   254  4.031583e+03  2.730115e+03   255   255  1595364685
# 4    4.0    31  1.846902e+06  4.032078e+06   255   255  1560901437
#
#         dtcpb  dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd  ct_srv_src  \
# 0           0       82  1424228654  ...             0         0.0           2
# 1           0        0  1424230503  ...             0         0.0          57
# 2  1621172393      463  1424219965  ...             0         0.0           3
# 3  3437994824       59  1424227838  ...             1         0.0           5
# 4  3710780746      189  1424224020  ...             0         0.0           7
#
#    ct_srv_dst  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 0           3            9                 1                 1
# 1          57           56                56                20
# 2           2            6                 1                 1
# 3           2            2                 2                 1
# 4           7            3                 2                 1
#
#    ct_dst_src_ltm  attack_cat  Label
# 0               1         8.0      0
# 1              57         8.0      0
# 2               1         8.0      0
# 3               2         8.0      0
# 4               3         8.0      0
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#   state  sttl         Sload         Dload  swin  dwin       stcpb       dtcpb  \
# 0   CON    31  5.047801e+05  6.271510e+05     0     0           0           0
# 1   INT    60  1.508571e+08  0.000000e+00     0     0           0           0
# 2   FIN    31  1.930670e+06  1.467602e+07   255   255  3749459648  1621172393
# 3   FIN   254  4.031583e+03  2.730115e+03   255   255  1595364685  3437994824
# 4   FIN    31  1.846902e+06  4.032078e+06   255   255  1560901437  3710780746
#
#    dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd ct_srv_src  ct_srv_dst  \
# 0       82  1424228654  ...             0                      2           3
# 1        0  1424230503  ...             0                     57          57
# 2      463  1424219965  ...             0                      3           2
# 3       59  1424227838  ...             1                      5           2
# 4      189  1424224020  ...             0                      7           7
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            9                 1                 1               1
# 1           56                56                20              57
# 2            6                 1                 1               1
# 3            2                 2                 1               2
# 4            3                 2                 1               3
#
#    attack_cat Label
# 0      Normal     0
# 1      Normal     0
# 2      Normal     0
# 3      Normal     0
# 4      Normal     0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Pre-processing

# %%
df.head()
# Out:
#   state  sttl         Sload         Dload  swin  dwin       stcpb       dtcpb  \
# 0   CON    31  5.047801e+05  6.271510e+05     0     0           0           0
# 1   INT    60  1.508571e+08  0.000000e+00     0     0           0           0
# 2   FIN    31  1.930670e+06  1.467602e+07   255   255  3749459648  1621172393
# 3   FIN   254  4.031583e+03  2.730115e+03   255   255  1595364685  3437994824
# 4   FIN    31  1.846902e+06  4.032078e+06   255   255  1560901437  3710780746
#
#    dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd ct_srv_src  ct_srv_dst  \
# 0       82  1424228654  ...             0                      2           3
# 1        0  1424230503  ...             0                     57          57
# 2      463  1424219965  ...             0                      3           2
# 3       59  1424227838  ...             1                      5           2
# 4      189  1424224020  ...             0                      7           7
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            9                 1                 1               1
# 1           56                56                20              57
# 2            6                 1                 1               1
# 3            2                 2                 1               2
# 4            3                 2                 1               3
#
#    attack_cat Label
# 0      Normal     0
# 1      Normal     0
# 2      Normal     0
# 3      Normal     0
# 4      Normal     0
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       state  sttl         Sload         Dload  swin  dwin       stcpb  \
# 92744   INT   254  1.520000e+08      0.000000     0     0           0
# 92745   FIN    62  2.534126e+03   8217.639648   255   255   211426311
# 92746   FIN   254  9.289192e+03   3055.475830   255   255   901831901
# 92747   FIN    62  3.693980e+03  10732.401370   255   255  1357488628
# 92748   FIN    62  7.843290e+03  18394.382810   255   255  2151897285
#
#             dtcpb  dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd  \
# 92744           0        0  1424231126  ...             2
# 92745  3288999294      317  1424231123  ...             1
# 92746  1184966395       45  1424231127  ...             1
# 92747  3378115145      142  1424231126  ...             1
# 92748  3110700255      253  1424231129  ...             1
#
#       ct_srv_src  ct_srv_dst  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 92744         34          34           19                19                19
# 92745          2           1            1                 1                 1
# 92746          6           2            2                 1                 1
# 92747          1           1            1                 1                 1
# 92748          2           1            1                 1                 1
#
#        ct_dst_src_ltm  attack_cat Label
# 92744              34     Generic     1
# 92745               1     Generic     1
# 92746               2    Fuzzers      1
# 92747               2    Exploits     1
# 92748               2         DoS     1
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (92749, 21)

# %%
df.size
# Out:
# 1947729

# %%
df.columns
# Out:
# Index(['state', 'sttl', 'Sload', 'Dload', 'swin', 'dwin', 'stcpb', 'dtcpb',
#        'dmeansz', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_ftp_cmd', 'ct_srv_src',
#        'ct_srv_dst', 'ct_src_ ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm',
#        'ct_dst_src_ltm', 'attack_cat', 'Label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92749 entries, 0 to 92748
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             92749 non-null  object
#  1   sttl              92749 non-null  int64
#  2   Sload             92749 non-null  float64
#  3   Dload             92749 non-null  float64
#  4   swin              92749 non-null  int64
#  5   dwin              92749 non-null  int64
#  6   stcpb             92749 non-null  int64
#  7   dtcpb             92749 non-null  int64
#  8   dmeansz           92749 non-null  int64
#  9   Stime             92749 non-null  int64
#  10  Ltime             92749 non-null  int64
#  11  ct_state_ttl      92749 non-null  int64
#  12  ct_ftp_cmd        92749 non-null  object
#  13  ct_srv_src        92749 non-null  int64
#  14  ct_srv_dst        92749 non-null  int64
#  15  ct_src_ ltm       92749 non-null  int64
#  16  ct_src_dport_ltm  92749 non-null  int64
#  17  ct_dst_sport_ltm  92749 non-null  int64
#  18  ct_dst_src_ltm    92749 non-null  int64
#  19  attack_cat        92749 non-null  object
#  20  Label             92749 non-null  int64
# dtypes: float64(2), int64(16), object(3)
# memory usage: 14.9+ MB

# %%
df.dtypes
# Out:
# state                object
# sttl                  int64
# Sload               float64
# Dload               float64
# swin                  int64
# dwin                  int64
# stcpb                 int64
# dtcpb                 int64
# dmeansz               int64
# Stime                 int64
# Ltime                 int64
# ct_state_ttl          int64
# ct_ftp_cmd           object
# ct_srv_src            int64
# ct_srv_dst            int64
# ct_src_ ltm           int64
# ct_src_dport_ltm      int64
# ct_dst_sport_ltm      int64
# ct_dst_src_ltm        int64
# attack_cat           object
# Label                 int64
# dtype: object

# %%
df.describe()
# Out:
#                sttl         Sload         Dload          swin          dwin  \
# count  92749.000000  9.274900e+04  9.274900e+04  92749.000000  92749.000000
# mean     149.376651  6.338480e+07  1.295593e+06    108.860742    108.778262
# std      109.523983  1.384780e+08  3.295951e+06    126.130883    126.118666
# min        0.000000  0.000000e+00  0.000000e+00      0.000000      0.000000
# 25%       31.000000  1.537925e+05  0.000000e+00      0.000000      0.000000
# 50%      254.000000  1.728588e+06  3.751337e+03      0.000000      0.000000
# 75%      254.000000  8.888889e+07  6.328125e+05    255.000000    255.000000
# max      255.000000  5.468000e+09  2.106510e+07    255.000000    255.000000
#
#               stcpb         dtcpb       dmeansz         Stime         Ltime  \
# count  9.274900e+04  9.274900e+04  92749.000000  9.274900e+04  9.274900e+04
# mean   9.204236e+08  9.186585e+08    168.139495  1.423646e+09  1.423646e+09
# std    1.340995e+09  1.337886e+09    293.612841  9.881519e+05  9.881519e+05
# min    0.000000e+00  0.000000e+00      0.000000  1.421956e+09  1.421956e+09
# 25%    0.000000e+00  0.000000e+00      0.000000  1.421972e+09  1.421972e+09
# 50%    0.000000e+00  0.000000e+00     45.000000  1.424224e+09  1.424224e+09
# 75%    1.797287e+09  1.792484e+09    119.000000  1.424229e+09  1.424229e+09
# max    4.294940e+09  4.294920e+09   1500.000000  1.424231e+09  1.424231e+09
#
#        ct_state_ttl    ct_srv_src    ct_srv_dst   ct_src_ ltm  \
# count  92749.000000  92749.000000  92749.000000  92749.000000
# mean       1.017585     10.737658     10.586292      7.650929
# std        0.953259     11.431927     11.484431      8.608757
# min        0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      2.000000      2.000000      2.000000
# 50%        1.000000      6.000000      6.000000      4.000000
# 75%        2.000000     17.000000     17.000000      9.000000
# max        6.000000     63.000000     62.000000     60.000000
#
#        ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm         Label
# count      92749.000000      92749.000000    92749.000000  92749.000000
# mean           5.869799          4.338451        9.477277      0.568729
# std            8.742057          6.046608       11.979133      0.495257
# min            1.000000          1.000000        1.000000      0.000000
# 25%            1.000000          1.000000        1.000000      0.000000
# 50%            1.000000          1.000000        3.000000      1.000000
# 75%            8.000000          7.000000       17.000000      1.000000
# max           60.000000         60.000000       63.000000      1.000000

# %%
df.isna().sum()
# Out:
# state               0
# sttl                0
# Sload               0
# Dload               0
# swin                0
# dwin                0
# stcpb               0
# dtcpb               0
# dmeansz             0
# Stime               0
# Ltime               0
# ct_state_ttl        0
# ct_ftp_cmd          0
# ct_srv_src          0
# ct_srv_dst          0
# ct_src_ ltm         0
# ct_src_dport_ltm    0
# ct_dst_sport_ltm    0
# ct_dst_src_ltm      0
# attack_cat          0
# Label               0
# dtype: int64

# %%
df["attack_cat"].value_counts()
# Out:
# Normal              40000
# Generic             27883
# Exploits            11103
#  Fuzzers             4668
# DoS                  4637
#  Reconnaissance      3115
# Analysis              608
# Backdoor              370
#  Shellcode            324
# Worms                  40
# Reconnaissance          1
# Name: attack_cat, dtype: int64

# %%
def bar_graph(feature):
    df[feature].value_counts().plot(kind="bar")

# %%
bar_graph('attack_cat')

# %%
df["state"].value_counts()
# Out:
# INT    42150
# FIN    39381
# CON    10967
# REQ      234
# RST        6
# ECO        6
# CLO        3
# ACC        2
# Name: state, dtype: int64

# %%
bar_graph("state")

# %%
df["ct_ftp_cmd"].value_counts()
# Out:
#      68142
# 0    23435
# 1     1156
# 2       12
# 4        4
# Name: ct_ftp_cmd, dtype: int64

# %%
bar_graph("ct_ftp_cmd")

# %%
df["ct_ftp_cmd"]
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 92744
# 92745
# 92746
# 92747
# 92748
# Name: ct_ftp_cmd, Length: 92749, dtype: object

# %%
def getXy():
    X = df2.drop(['Label'], axis=1)
    y = df2["Label"]
    
    return (X,y)

# %%
from sklearn.model_selection import train_test_split

def getSplittedXy(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)
    return (X_train,X_test ,y_train, y_test, )

# %%
df.head()
# Out:
#   state  sttl         Sload         Dload  swin  dwin       stcpb       dtcpb  \
# 0   CON    31  5.047801e+05  6.271510e+05     0     0           0           0
# 1   INT    60  1.508571e+08  0.000000e+00     0     0           0           0
# 2   FIN    31  1.930670e+06  1.467602e+07   255   255  3749459648  1621172393
# 3   FIN   254  4.031583e+03  2.730115e+03   255   255  1595364685  3437994824
# 4   FIN    31  1.846902e+06  4.032078e+06   255   255  1560901437  3710780746
#
#    dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd ct_srv_src  ct_srv_dst  \
# 0       82  1424228654  ...             0                      2           3
# 1        0  1424230503  ...             0                     57          57
# 2      463  1424219965  ...             0                      3           2
# 3       59  1424227838  ...             1                      5           2
# 4      189  1424224020  ...             0                      7           7
#
#    ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0            9                 1                 1               1
# 1           56                56                20              57
# 2            6                 1                 1               1
# 3            2                 2                 1               2
# 4            3                 2                 1               3
#
#    attack_cat Label
# 0      Normal     0
# 1      Normal     0
# 2      Normal     0
# 3      Normal     0
# 4      Normal     0
#
# [5 rows x 21 columns]

# %%
df2.head()
# Out:
#    state  sttl         Sload         Dload  swin  dwin       stcpb  \
# 0    2.0    31  5.047801e+05  6.271510e+05     0     0           0
# 1    5.0    60  1.508571e+08  0.000000e+00     0     0           0
# 2    4.0    31  1.930670e+06  1.467602e+07   255   255  3749459648
# 3    4.0   254  4.031583e+03  2.730115e+03   255   255  1595364685
# 4    4.0    31  1.846902e+06  4.032078e+06   255   255  1560901437
#
#         dtcpb  dmeansz       Stime  ...  ct_state_ttl  ct_ftp_cmd  ct_srv_src  \
# 0           0       82  1424228654  ...             0         0.0           2
# 1           0        0  1424230503  ...             0         0.0          57
# 2  1621172393      463  1424219965  ...             0         0.0           3
# 3  3437994824       59  1424227838  ...             1         0.0           5
# 4  3710780746      189  1424224020  ...             0         0.0           7
#
#    ct_srv_dst  ct_src_ ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# 0           3            9                 1                 1
# 1          57           56                56                20
# 2           2            6                 1                 1
# 3           2            2                 2                 1
# 4           7            3                 2                 1
#
#    ct_dst_src_ltm  attack_cat  Label
# 0               1         8.0      0
# 1              57         8.0      0
# 2               1         8.0      0
# 3               2         8.0      0
# 4               3         8.0      0
#
# [5 rows x 21 columns]

# %%
df.to_csv("df_reduced_feature.csv")
df2.to_csv("df_reduced_feature_encoded.csv")

# %% [markdown]
# ##### In this notebook features are encoded with OridinalEncoder and are reduced based on correlation and usaility. Finally the two datasets i.e original and encoded are saved in a new csv file
